# %% [markdown]
# # 6.4  무선청소기 모델별 비교 분석

# %% [markdown]
# ### 6.4.1 데이터 살펴보기

# %%
# 예제 6-34 데이터 불러오기 
import pandas as pd
danawa_data = pd.read_excel('./files/3_2_danawa_data_final.xlsx')
danawa_data.info()
danawa_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   카테고리    288 non-null    object
#  1   회사명     288 non-null    object
#  2   제품      288 non-null    object
#  3   가격      288 non-null    int64
#  4   사용시간    269 non-null    float64
#  5   흡입력     173 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 13.6+ KB
#        카테고리   회사명                            제품       가격  사용시간    흡입력
# 0  핸디/스틱청소기  LG전자  오브제컬렉션 코드제로 ThinQ A9S AO9571  1194300  60.0  210.0
# 1  핸디/스틱청소기  LG전자                코드제로 A9 A9100S   488350  40.0  140.0
# 2  핸디/스틱청소기  삼성전자            비스포크 제트 VS20A956A3   786660  60.0  210.0
# 3  핸디/스틱청소기   샤오미                       드리미 V10        0  60.0  220.0
# 4  핸디/스틱청소기   샤오미              TROUVER POWER 11   153660  60.0    NaN

# %%
# 예제 6-35 흡입력 기준 정렬
top_list = danawa_data.sort_values(["흡입력"], ascending = False)
top_list.head()
# Out:
#          카테고리    회사명               제품      가격   사용시간    흡입력
# 209  핸디/스틱청소기    리하스             LH20   51900  120.0  330.0
# 175  핸디/스틱청소기    캐치웰           NEW F8  789860   25.0  290.0
# 96   핸디/스틱청소기  DIBEA  차이슨 ALLNEW29000  260600   48.0  290.0
# 179  핸디/스틱청소기    퍼피유             T12R  468390   60.0  290.0
# 49   핸디/스틱청소기    샤오미          드리미 V12   29350   90.0  270.0

# %%
# 예제 6-36 사용시간 기준 정렬
top_list = danawa_data.sort_values(["사용시간"], ascending = False)
top_list.head()
# Out:
#          카테고리  회사명                   제품      가격   사용시간    흡입력
# 209  핸디/스틱청소기  리하스                 LH20   51900  120.0  330.0
# 49   핸디/스틱청소기  샤오미              드리미 V12   29350   90.0  270.0
# 205  핸디/스틱청소기  로보락                   H6  360000   90.0  250.0
# 65   핸디/스틱청소기  샤오미              드리미 V11  169000   90.0  250.0
# 99   핸디/스틱청소기   모온  오비큠 플러스 이지클린 + 펫큠세트  185250   80.0    NaN

# %%
# 예제 6-37 흡입력, 사용시간을 기준으로 정렬
# 흡입력 & 사용시간 TOP 리스트
top_list = danawa_data.sort_values(["사용시간","흡입력"], ascending = False)
top_list.head()
# Out:
#          카테고리  회사명                   제품      가격   사용시간    흡입력
# 209  핸디/스틱청소기  리하스                 LH20   51900  120.0  330.0
# 49   핸디/스틱청소기  샤오미              드리미 V12   29350   90.0  270.0
# 65   핸디/스틱청소기  샤오미              드리미 V11  169000   90.0  250.0
# 205  핸디/스틱청소기  로보락                   H6  360000   90.0  250.0
# 99   핸디/스틱청소기   모온  오비큠 플러스 이지클린 + 펫큠세트  185250   80.0    NaN

# %%
# 예제 6-38 평균값 정리
price_mean_value = danawa_data['가격'].mean()
suction_mean_value = danawa_data['흡입력'].mean()
use_time_mean_value = danawa_data['사용시간'].mean()
print("가격 평균값", price_mean_value)
print("흡입력 평균값", suction_mean_value)
print("사용시간 평균값", use_time_mean_value)
# Out:
# 가격 평균값 344324.10069444444
# 흡입력 평균값 177.31791907514452
# 사용시간 평균값 44.51672862453532

# %%
# 예제 6-39 가성비 좋은 제품 탐색
condition_data = danawa_data [
    (danawa_data['가격'] <= price_mean_value) & 
    (danawa_data['흡입력'] >= suction_mean_value) & 
    (danawa_data['사용시간'] >= use_time_mean_value)]
condition_data
# Out:
#          카테고리    회사명                      제품      가격   사용시간    흡입력
# 3    핸디/스틱청소기    샤오미                 드리미 V10       0   60.0  220.0
# 5    핸디/스틱청소기   삼성전자        제트 VS20T9218QDCC  136590   60.0  200.0
# 7    핸디/스틱청소기   삼성전자        제트 VS20T9278S3CS  145470   60.0  200.0
# 12   핸디/스틱청소기   삼성전자      비스포크 제트 VS20A957E3   51510   60.0  210.0
# 19   핸디/스틱청소기    다이슨                V11 컴플리트   59340   60.0  185.0
# 24   핸디/스틱청소기   삼성전자        제트 VS20T9253QDCS  125010   60.0  200.0
# 26   핸디/스틱청소기   LG전자    코드제로 ThinQ A9S A9300  116410   60.0  200.0
# 27   핸디/스틱청소기   LG전자    코드제로 ThinQ A9S A9500   75510   60.0  200.0
# 34   핸디/스틱청소기   삼성전자          제트 VS20T9278S3   38190   60.0  200.0
# 40   핸디/스틱청소기   LG전자    코드제로 ThinQ A9S A9570   48900   60.0  200.0
# 42   핸디/스틱청소기   삼성전자          제트 VS20T9257SD       0   60.0  200.0
# 46   핸디/스틱청소기   삼성전자          제트 VS20R9078S2   72930   60.0  200.0
# 49   핸디/스틱청소기    샤오미                 드리미 V12   29350   90.0  270.0
# 53   핸디/스틱청소기    다이슨        V11 220 에어와트 CF+  298200   60.0  220.0
# 58   핸디/스틱청소기    샤오미                드리미 V10P   36200   60.0  220.0
# 60   핸디/스틱청소기   삼성전자        제트 VS20T9279S6CS   78680   60.0  200.0
# 62   핸디/스틱청소기    샤오미         SHUNZAO Z11 PRO  122680   60.0  260.0
# 63   핸디/스틱청소기   LG전자  코드제로 ThinQ A9S A9470IK   70720   60.0  200.0
# 65   핸디/스틱청소기    샤오미                 드리미 V11  169000   90.0  250.0
# 75   핸디/스틱청소기   삼성전자          제트 VS20R9043SA  169000   60.0  200.0
# 79   핸디/스틱청소기    샤오미            로이드미 X30 Pro  258000   70.0  265.0
# 94   핸디/스틱청소기  원더스리빙             원더스 다이나킹 Z9  155000   65.0  220.0
# 96   핸디/스틱청소기  DIBEA         차이슨 ALLNEW29000  260600   48.0  290.0
# 128  핸디/스틱청소기    오토모               AVC-OTOA5   87580   60.0  200.0
# 141  핸디/스틱청소기    샤오미             로이드미 Z1 Air  335350   60.0  220.0
# 145  핸디/스틱청소기    샤오미                 드리미 V9P   56860   60.0  200.0
# 146  핸디/스틱청소기   삼성전자       제트 VS20T9213QDCSW   61000   60.0  200.0
# 147  핸디/스틱청소기    보아스                VO1000PG  266490   50.0  250.0
# 157  핸디/스틱청소기    샤오미            드리미 V10 ARES   27240   60.0  220.0
# 162  핸디/스틱청소기   삼성전자        제트 VS20T9259SECC  185510   60.0  200.0
# 166  핸디/스틱청소기   삼성전자          제트 VS20R9043QA  268190   60.0  200.0
# 169  핸디/스틱청소기   삼성전자        제트 VS20T9213QDCS   74700   60.0  200.0
# 181  핸디/스틱청소기    샤오미     TROUVER TECH SOLO10   69000   48.0  180.0
# 188  핸디/스틱청소기    샤오미                 로이드미 Z1  225280   60.0  220.0
# 195  핸디/스틱청소기    샤오미                 드리미 T20       0   70.0  250.0
# 198  핸디/스틱청소기  DIBEA              TSX-25000A  239170   45.0  250.0
# 200  핸디/스틱청소기   삼성전자      비스포크 제트 VS20A957D3   39800   60.0  210.0
# 203  핸디/스틱청소기   삼성전자        제트 VS20T9257SECC   37150   60.0  200.0
# 207  핸디/스틱청소기    다이슨           V11 컴플리트 엑스트라   97650   60.0  220.0
# 209  핸디/스틱청소기    리하스                    LH20   51900  120.0  330.0
# 217  핸디/스틱청소기   삼성전자      비스포크 제트 VS20A957F3   64510   60.0  210.0
# 230  핸디/스틱청소기    델로라             V11 파워 300W   33580   70.0  220.0
# 236  핸디/스틱청소기   LG전자   코드제로 ThinQ A9S AS9571  139000   60.0  210.0
# 237  핸디/스틱청소기  DIBEA                 M24 MAX   44550   50.0  250.0
# 238  핸디/스틱청소기    샤오미      VIOMI A9 V-HWVC12A   91650   60.0  230.0
# 252  핸디/스틱청소기    오토모               AVC-OTOA6   38120   60.0  200.0
# 253  핸디/스틱청소기   삼성전자          제트 VS20T9279S6   29130   60.0  200.0
# 260  핸디/스틱청소기   삼성전자        제트 VS20T9213QDCC  168600   60.0  200.0
# 261  핸디/스틱청소기    샤오미             지미 JV85 Pro       0   70.0  250.0
# 262  핸디/스틱청소기    다이슨                V11 플러피+  308620   60.0  220.0
# 271  핸디/스틱청소기    보아르                  포스 B25   81880   60.0  250.0
# 286  핸디/스틱청소기    다이슨                V11 토탈클린       0   60.0  185.0

# %% [markdown]
# ### 6.4.3 데이터 시각화

# %%
# 예제 6-40 라이브러리 임포트 및 한글 글꼴 설정
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
import seaborn as sns
import platform 
# 그래프에서 한글 표기를 위한 글꼴 변경(윈도우, macOS에 대해 처리)
font_path = ''
if platform.system() == 'Windows': 
    font_path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname = font_path).get_name()
    rc('font', family = font_name)
elif platform.system() == 'Darwin':
    font_path = '/Users/$USER/Library/Fonts/AppleGothic.ttf'
    rc('font', family = 'AppleGothic')
else: 
    print('Check your OS system')
    
# %matplotlib inline

# %%
# 예제 6-41 결측값 없애기
chart_data = danawa_data.dropna(axis = 0)
len(chart_data)
# Out:
# 170

# %%
# 예제 6-42 흡입력, 사용시간의 최댓값/최솟값 정리
# 흡입력, 사용사간 최대, 최소
suction_max_value = chart_data['흡입력'].max()
suction_mean_value = chart_data['흡입력'].mean()
use_time_max_value = chart_data['사용시간'].max()
use_time_mean_value = chart_data['사용시간'].mean()

# %%
# 예제 6-43 청소기 성능 시각화
plt.figure(figsize=(20, 10))
plt.title("무선 핸디/스틱청소기 차트")
sns.scatterplot(x = '흡입력', y = '사용시간', size = '가격', hue = chart_data['회사명'], 
             data = chart_data, sizes = (10, 1000), legend = False)
plt.plot([0, suction_max_value], 
          [use_time_mean_value, use_time_mean_value], 
          'r--', 
          lw = 1 )
plt.plot([suction_mean_value, suction_mean_value], 
          [0, use_time_max_value], 
          'r--', 
          lw = 1 )
plt.show()

# %% [markdown]
# ### 6.4.4 인기 제품의 데이터 시각화

# %%
# 예제 6-44 인기 제품 선택
chart_data_selected = chart_data[:20]
len(chart_data_selected)
# Out:
# 20

# %%
# 예제 6-45 흡입력, 사용시간의 최댓값/최솟값 정리
# 흡입력, 사용시간의 최댓값, 최솟값 구하기
suction_max_value = chart_data_selected['흡입력'].max()
suction_mean_value = chart_data_selected['흡입력'].mean()
use_time_max_value = chart_data_selected['사용시간'].max()
use_time_mean_value = chart_data_selected['사용시간'].mean()
plt.figure(figsize=(20, 10))
plt.title("무선 핸디/스틱청소기 TOP 20")
sns.scatterplot(x = '흡입력', 
                  y = '사용시간', 
                  size = '가격', 
                  hue = chart_data_selected['회사명'], 
                  data = chart_data_selected, sizes = (100, 2000),
                  legend = False)
plt.plot([60, suction_max_value], 
          [use_time_mean_value, use_time_mean_value], 
          'r--', 
          lw = 1 )
plt.plot([suction_mean_value, suction_mean_value], 
          [20, use_time_max_value], 
          'r--', 
          lw = 1 )
for index, row in chart_data_selected.iterrows():
    x = row['흡입력']
    y = row['사용시간']
    s = row['제품'].split(' ')[0]
    plt.text(x, y, s, size=20)
plt.show()
