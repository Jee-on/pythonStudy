# %%
import pymysql
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
from urllib.parse import urlparse
import json
import re
import folium

# %%
#전역변수 선언부
conn = None
cur = None

data1 = ""
sql = ""

# %%
###디비연동 시작
try:
    conn = pymysql.connect(host='192.168.0.20', user='root', password='722500', db='hollys', charset='utf8')
    cur = conn.cursor()
except Exception as e:
    print(e)

# %%
###크롤링 시작
driver = webdriver.Chrome('./webdriver/chromedriver.exe')
driver.implicitly_wait(3)

page_no = 2
bol = True
while(bol):
    try:
        driver.get('https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=%d&sido=&gugun=&store=' %page_no)
        page_no +=1
    except Exception as e:
        print(e)
        break
    
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    store = []
    for i in soup.select("tbody>tr"):
        try:
            name  = i.select_one("td:nth-child(2)").text
            tel   = i.select_one("td:last-child").text
            x  = i.select_one("td:nth-child(4)").text
        except Exception as e:
            print(e)
            bol=False
        
        #re.sub으로 괄호안의 값 제거, split으로 주소가 두개인곳 한개 제거
        #replace로 '.' 제거, rstrip으로 우 공백제거
        pattern = r'\([^)]*\)'
        addr = re.sub(pattern=pattern, repl='', string=x).split(',')[0].replace('.',"").rstrip()
        
        #딕셔너리 선언후 각 키에 맞는 값 넣어줌
        store_dict = {'name': name, 'tel':tel, 'addr':addr}
        #리스트 store에 append
        store.append(store_dict)    
     # 데이터 입력 시작
    for i in store:
        try:
            sql = "INSERT INTO hollys(매장명,전화번호,주소) VALUES('{}','{}','{}')".format(i['name']
                                                                                  ,i['tel']
                                                                                  ,i['addr'])
            cur.execute(sql)
            print(sql)
            conn.commit()
        except Exception as e:
            print(e)

# %%
# 매장명, 주소로 db저장된값 출력
sql = 'select 매장명,주소 from hollys'
cur.execute(sql)
dbAddr = cur.fetchall()
# foluum 지도 생성
m = folium.Map(location=[37.559819, 126.963895]
               ,zoom_start=10
               ,tiles='cartodbpositron')

# %%
# db정보로 folium 지도에 mark
for i in dbAddr:
    url = f"https://dapi.kakao.com/v2/local/search/address.json?query={i[1]}"
    result = requests.get(urlparse(url).geturl(),
                          headers={"Authorization": "KakaoAK 115d822f80eb6f46749c998bf47d3b5c"}).json()
    print(json.dumps(result, indent=4, ensure_ascii=False))
    try:
        lat = result["documents"][0]["x"]
        lng = result["documents"][0]["y"]
        folium.Marker([lng,lat]
                      ,popup="{}".format(i[0])
                      ,tooltip="{}".format(i[0])).add_to(m)
        sql = "update hollys set 위도='{}',경도='{}' where 매장명='{}'".format(lat,lng,i[0])
        print(sql)
        cur.execute(sql)
        conn.commit()
        print("매장명:",i[0],"위도:",lat,"경도:",lng)
        
    except Exception as e:
        print(e)
        pass

# %%
# 지도저장

# db 연결종료
conn.commit()
cur.close()
conn.close()
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7faccdea476d9cfcaf6cee7b47d1bcc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7faccdea476d9cfcaf6cee7b47d1bcc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7faccdea476d9cfcaf6cee7b47d1bcc8 = L.map(
#                 &quot;map_7faccdea476d9cfcaf6cee7b47d1bcc8&quot;,
#                 {
#                     center: [37.559819, 126.963895],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_124d0efb10de4b00746302b31d8dd01a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7faccdea476d9cfcaf6cee7b47d1bcc8);
#
#
#             var marker_f5ecd88bfbecf58ebc524e0f2d931f4a = L.marker(
#                 [36.3191630806256, 127.070040988938],
#                 {}
#             ).addTo(map_7faccdea476d9cfcaf6cee7b47d1bcc8);
#
#
#         var popup_5d5ed522a50dc0e5a4609fd1a5e41633 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24d6e49f86c7ee8db0ae1e26c387cd9e = $(`&lt;div id=&quot;html_24d6e49f86c7ee8db0ae1e26c387cd9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(논)탄천휴게소2호점&lt;/div&gt;`)[0];
#                 popup_5d5ed522a50dc0e5a4609fd1a5e41633.setContent(html_24d6e49f86c7ee8db0ae1e26c387cd9e);
#
#
#
#         marker_f5ecd88bfbecf58ebc524e0f2d931f4a.bindPopup(popup_5d5ed522a50dc0e5a4609fd1a5e41633)
#         ;
#
#
#
#
#             marker_f5ecd88bfbecf58ebc524e0f2d931f4a.bindTooltip(
#                 `&lt;div&gt;
#                      (논)탄천휴게소2호점
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bd0c7383c32e54969232bf62800ede51 = L.marker(
#                 [36.3191630806256, 127.070040988938],
#                 {}
#             ).addTo(map_7faccdea476d9cfcaf6cee7b47d1bcc8);
#
#
#         var popup_93454f53ce0fb5d0c14d1dae0b8c2e91 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee946cf33bcd12a2a9747ba862e31e6d = $(`&lt;div id=&quot;html_ee946cf33bcd12a2a9747ba862e31e6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(논)탄천휴게소점&lt;/div&gt;`)[0];
#                 popup_93454f53ce0fb5d0c14d1dae0b8c2e91.setContent(html_ee946cf33bcd12a2a9747ba862e31e6d);
#
#
#
#         marker_bd0c7383c32e54969232bf62800ede51.bindPopup(popup_93454f53ce0fb5d0c14d1dae0b8c2e91)
#         ;
#
#
#
#
#             marker_bd0c7383c32e54969232bf62800ede51.bindTooltip(
#                 `&lt;div&gt;
#                      (논)탄천휴게소점
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9e95c5e16b30d533df8924e8b5309800 = L.marker(
#                 [37.2536358076338, 128.048658735614],
#                 {}
#             ).addTo(map_7faccdea476d9cfcaf6cee7b47d1bcc8);
#
#
#         var popup_6882081d7a068519c83c7a206aadc91c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a3e03f40f7b73f7cca9b87c718513a5 = $(`&lt;div id=&quot;html_7a3e03f40f7b73f7cca9b87c718513a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(부)치악휴게소점&lt;/div&gt;`)[0];
#                 popup_6882081d7a068519c83c7a206aadc91c.setContent(html_7a3e03f40f7b73f7cca9b87c718513a5);
#
#
#
#         marker_9e95c5e16b30d533df8924e8b5309800.bindPopup(popup_6882081d7a068519c83c7a206aadc91c)
#         ;
#
#
#
#
#             marker_9e95c5e16b30d533df8924e8b5309800.bindTooltip(
#                 `&lt;div&gt;
#                      (부)치악휴게소점
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c0111bd8ec2049628e700d4c40e0c5ee = L.marker(
#                 [35.7062960150696, 128.056972292119],
#                 {}
#             ).addTo(map_7faccdea476d9cfcaf6cee7b47d1bcc8);
#
#
#         var popup_de6392ca3e3164bd967c58b3100e904e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7547f193b0f276905fd0ef3e8969041e = $(`&lt;div id=&quot;html_7547f193b0f276905fd0ef3e8969041e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(상)거창휴게소점&lt;/div&gt;`)[0];
#                 popup_de6392ca3e3164bd967c58b3100e904e.setContent(html_7547f193b0f276905fd0ef3e8969041e);
#
#
#
#         marker_c0111bd8ec2049628e700d4c40e0c5ee.bindPopup(popup_de6392ca3e3164bd967c58b3100e904e)
#         ;

# %% [markdown]
# ![지도](hollys.png)
